# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## A Glance at Data

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('data/Concrete_Data_Yeh.csv')
df.head(3)
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27

# %% [markdown]
# #### Basic info about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# cement              1030 non-null float64
# slag                1030 non-null float64
# flyash              1030 non-null float64
# water               1030 non-null float64
# superplasticizer    1030 non-null float64
# coarseaggregate     1030 non-null float64
# fineaggregate       1030 non-null float64
# age                 1030 non-null int64
# csMPa               1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# min         801.000000     594.000000     1.000000     2.330000
# 25%         932.000000     730.950000     7.000000    23.710000
# 50%         968.000000     779.500000    28.000000    34.445000
# 75%        1029.400000     824.000000    56.000000    46.135000
# max        1145.000000     992.600000   365.000000    82.600000

# %% [markdown]
# ##### To see the distribution of the the data.

# %%
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# ## Create Test data
#
# **Note** : Try to make test data as similar as complete data. The test data should represent the whole population.

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=0)

# %% [markdown]
# ### Compare test data to the complete data

# %% [markdown]
# #### Stats of data

# %%
df.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# min         801.000000     594.000000     1.000000     2.330000
# 25%         932.000000     730.950000     7.000000    23.710000
# 50%         968.000000     779.500000    28.000000    34.445000
# 75%        1029.400000     824.000000    56.000000    46.135000
# max        1145.000000     992.600000   365.000000    82.600000

# %%
test_df.describe()
# Out:
#            cement        slag      flyash       water  superplasticizer  \
# count  206.000000  206.000000  206.000000  206.000000        206.000000
# mean   288.517961   58.505825   52.733981  182.250000          5.733981
# std    103.854191   75.977524   62.045375   21.141435          5.984517
# min    102.000000    0.000000    0.000000  126.600000          0.000000
# 25%    212.000000    0.000000    0.000000  163.200000          0.000000
# 50%    284.000000   14.300000    0.000000  185.000000          5.800000
# 75%    350.000000  116.000000  106.850000  193.000000          9.850000
# max    540.000000  316.100000  195.000000  246.900000         32.200000
#
#        coarseaggregate  fineaggregate         age       csMPa
# count       206.000000     206.000000  206.000000  206.000000
# mean        977.516019     775.200000   45.135922   34.686311
# std          77.679988      76.420853   68.470047   16.268510
# min         801.000000     594.000000    3.000000    4.570000
# 25%         932.000000     732.700000    7.000000   22.555000
# 50%         970.900000     781.500000   28.000000   33.740000
# 75%        1029.525000     826.475000   28.000000   45.545000
# max        1134.300000     992.600000  365.000000   79.300000

# %% [markdown]
# #### Distribution of target variable

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
df.csMPa.hist(bins=50, ax=ax[0], );test_df.csMPa.hist(bins=50, ax=ax[1])
ax[0].title.set_text('Complete data csMPa');ax[1].title.set_text('Test data csMPa')

# %% [markdown]
# Both are looking kinda similar which is good.

# %% [markdown]
# #### Compare the ranges of target variable in Complete and Test data

# %%
temp_com_df = pd.DataFrame()
temp_com_df['Complete_csMPa_cat5'] = pd.cut(df.csMPa, bins=[0, 20, 40, 60, 80, 100],
                                            labels=['A', 'B', 'C', 'D', 'E'])
temp_com_df['Complete_csMPa_cat4'] = pd.cut(df.csMPa, bins=[0, 20, 40, 60, 100], labels=['A', 'B', 'C', 'D'])

temp_test_df = pd.DataFrame()
temp_test_df['Test_csMPa_cat5'] = pd.cut(test_df.csMPa, bins=[0, 20, 40, 60, 80, 100],
                                            labels=['A', 'B', 'C', 'D', 'E'])
temp_test_df['Test_csMPa_cat4'] = pd.cut(test_df.csMPa, bins=[0, 20, 40, 60, 100], labels=['A', 'B', 'C', 'D'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
temp_com_df.Complete_csMPa_cat4.hist(ax=ax)
temp_test_df.Test_csMPa_cat4.hist(ax=ax)
ax.title.set_text('Complete & Test csMPa with 4 categories')

# %%
print(temp_com_df.Complete_csMPa_cat4.value_counts()/len(temp_com_df))
print(temp_test_df.Test_csMPa_cat4.value_counts()/len(temp_test_df))
# Out:
# B    0.440777
# C    0.276699
# A    0.191262
# D    0.091262
# Name: Complete_csMPa_cat4, dtype: float64
# B    0.441748
# C    0.262136
# A    0.213592
# D    0.082524
# Name: Test_csMPa_cat4, dtype: float64

# %% [markdown]
# Test data has almost equal distribution of target variable (csMPa) as in Complete data i.e Test data is very similar to Complete data.

# %% [markdown]
# ### Save train, test data

# %%
train_df.to_csv('data/train.csv', index=False)
test_df.to_csv('data/test.csv', index=False)

# %% [markdown]
# ## EDA on Train data

# %% [markdown]
# ### Read Train data

# %%
train_df = pd.read_csv('data/train.csv')
train_df.head(2)
# Out:
#    cement  slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   480.0   0.0     0.0  192.0               0.0            936.0
# 1   375.0   0.0     0.0  186.0               0.0           1038.0
#
#    fineaggregate  age  csMPa
# 0          721.0   28  43.89
# 1          758.0   28  38.21

# %% [markdown]
# #### Basic info about train data

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 9 columns):
# cement              824 non-null float64
# slag                824 non-null float64
# flyash              824 non-null float64
# water               824 non-null float64
# superplasticizer    824 non-null float64
# coarseaggregate     824 non-null float64
# fineaggregate       824 non-null float64
# age                 824 non-null int64
# csMPa               824 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 58.1 KB

# %%
train_df.describe()
# Out:
#            cement        slag      flyash       water  superplasticizer  \
# count  824.000000  824.000000  824.000000  824.000000        824.000000
# mean   279.330340   77.743325   54.551942  181.396602          6.322330
# std    104.650827   88.291707   64.507395   21.416425          5.969006
# min    102.000000    0.000000    0.000000  121.800000          0.000000
# 25%    190.700000    0.000000    0.000000  164.900000          0.000000
# 50%    265.500000   25.000000    0.000000  185.000000          6.550000
# 75%    355.000000  148.925000  118.300000  192.000000         10.300000
# max    540.000000  359.400000  200.100000  247.000000         32.200000
#
#        coarseaggregate  fineaggregate         age       csMPa
# count       824.000000     824.000000  824.000000  824.000000
# mean        971.769660     773.175607   45.793689   36.100874
# std          77.777084      81.127383   61.817539   16.811051
# min         801.000000     594.000000    1.000000    2.330000
# 25%         932.000000     730.300000   14.000000   23.777500
# 50%         967.050000     778.500000   28.000000   34.755000
# 75%        1029.400000     824.000000   56.000000   46.232500
# max        1145.000000     992.600000  365.000000   82.600000

# %% [markdown]
# ### Histogram distribution for all features

# %%
train_df.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# ### Correlation between features

# %%
plt.figure(figsize=(10,10))
ax = sns.heatmap(train_df.corr(),  vmin=-1, vmax=1, center=0,square=True, annot=True, cmap="YlGnBu")
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=30,
    fontsize=10,
    horizontalalignment='right'
)
ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=30,
    fontsize=10,
    horizontalalignment='right'
)
ax.set_ylim(9, 0);

# %% [markdown]
# ### Scatter plots
#
# For High correlated features

# %% [markdown]
# #### Normal Density

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
train_df.plot(kind='scatter', x='cement', y='csMPa', ax=ax[0, 0])
train_df.plot(kind='scatter', x='water', y='csMPa', ax=ax[0, 1])
train_df.plot(kind='scatter', x='superplasticizer', y='csMPa', ax=ax[1, 0])
train_df.plot(kind='scatter', x='age', y='csMPa', ax=ax[1, 1])

# %% [markdown]
# #### High vs Low density

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
train_df.plot(kind='scatter', x='cement', y='csMPa', ax=ax[0, 0], alpha=0.1)
train_df.plot(kind='scatter', x='water', y='csMPa', ax=ax[0, 1], alpha=0.1)
train_df.plot(kind='scatter', x='superplasticizer', y='csMPa', ax=ax[1, 0], alpha=0.1)
train_df.plot(kind='scatter', x='age', y='csMPa', ax=ax[1, 1], alpha=0.1)

# %% [markdown]
# ### Create Categorical features for plotting

# %% [markdown]
# #### Flyash categorical

# %%
train_df.loc[train_df.flyash == 0, 'flyash_cat'] = '0'
train_df.loc[(train_df.flyash  > 0) & (train_df.flyash  <= 75), 'flyash_cat'] = '0-75'
train_df.loc[(train_df.flyash  > 75) & (train_df.flyash  <= 100), 'flyash_cat'] = '76-100'
train_df.loc[(train_df.flyash  > 100) & (train_df.flyash  <= 125), 'flyash_cat'] = '101-125'
train_df.loc[(train_df.flyash  > 125) & (train_df.flyash  <= 150), 'flyash_cat'] = '126-150'
train_df.loc[(train_df.flyash  > 150) & (train_df.flyash  <= 175), 'flyash_cat'] = '151-175'
train_df.loc[(train_df.flyash  > 175), 'flyash_cat'] = '>175'

# %% [markdown]
# #### Slag categorical

# %%
train_df.loc[train_df.slag == 0, 'slag_cat'] = '0'
train_df.loc[(train_df.slag  > 0) & (train_df.slag  <= 50), 'slag_cat'] = '0-50'
train_df.loc[(train_df.slag  > 50) & (train_df.slag  <= 100), 'slag_cat'] = '51-100'
train_df.loc[(train_df.slag  > 100) & (train_df.slag  <= 150), 'slag_cat'] = '101-150'
train_df.loc[(train_df.slag  > 150) & (train_df.slag  <= 200), 'slag_cat'] = '151-200'
train_df.loc[(train_df.slag  > 200) & (train_df.slag  <= 250), 'slag_cat'] = '201-250'
train_df.loc[(train_df.slag  > 250) & (train_df.slag  <= 300), 'slag_cat'] = '251-300'
train_df.loc[(train_df.slag  > 300) & (train_df.slag  <= 350), 'slag_cat'] = '301-350'
train_df.loc[(train_df.slag  > 350), 'slag_cat'] = '>350'

# %% [markdown]
# #### Superplasticizer categorical

# %%
train_df.loc[train_df.superplasticizer == 0, 'superplasticizer_cat'] = '0'
train_df.loc[(train_df.superplasticizer  > 0) & (train_df.superplasticizer  <= 5), 
             'superplasticizer_cat'] = '0-5'
train_df.loc[(train_df.superplasticizer  > 5) & (train_df.superplasticizer  <= 10), 
             'superplasticizer_cat'] = '6-10'
train_df.loc[(train_df.superplasticizer  > 10) & (train_df.superplasticizer  <= 15), 
             'superplasticizer_cat'] = '11-15'
train_df.loc[(train_df.superplasticizer  > 15) & (train_df.superplasticizer  <= 20), 
             'superplasticizer_cat'] = '16-20'
train_df.loc[train_df.superplasticizer  > 20, 'superplasticizer_cat'] = '>20'

# %% [markdown]
# #### Plot Flyash categorical, Slag categorical and Superplasticizer categorical vs csMPa

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 12))
sns.catplot('age', 'csMPa', data=train_df, kind='point', ax=ax[0,0])
sns.catplot('flyash_cat', 'csMPa', data=train_df, kind='point', ax=ax[0, 1])
sns.catplot('slag_cat', 'csMPa', data=train_df, kind='point', ax=ax[1, 0])
sns.catplot('superplasticizer_cat', 'csMPa', data=train_df, kind='point', ax=ax[1, 1])
ax[0, 1].set_xticklabels(
    ax[0, 1].get_xticklabels(),
    rotation=30,
    fontsize=10,
    horizontalalignment='right'
)
ax[1, 0].set_xticklabels(
    ax[1, 0].get_xticklabels(),
    rotation=30,
    fontsize=10,
    horizontalalignment='right'
)
plt.close(2); plt.close(3); plt.close(4); plt.close(5)

# %% [markdown]
# ### EDA Summary (train data)

# %% [markdown]
# - Most of the data points have age less than 29 years.
# - Flyash, Slag and Superplasticizer mostly have data points with value zero.
# - Cement, Water, Superplasticizer and Age are highly correlated.
# - csMPa power is almost linearly incresing with age upto 91 (except at 90) and also has max value at 91. After 91 the csMPa power is decresing.
# - csMPa power is decreasing for flyash value greater than 175.
# - csMPa power is almost linearly increasing with superplasticizer.

# %% [markdown]
# ## Model Training

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import eli5
from eli5.sklearn import PermutationImportance

import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/MohdSaqib/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/MohdSaqib/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ### Read Train Data

# %%
train_df = pd.read_csv('data/train.csv')
train_df.head(3)
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   480.0    0.0     0.0  192.0               0.0            936.0
# 1   375.0    0.0     0.0  186.0               0.0           1038.0
# 2   303.6  139.9     0.0  213.5               6.2            895.5
#
#    fineaggregate  age  csMPa
# 0          721.0   28  43.89
# 1          758.0   28  38.21
# 2          722.5   28  33.42

# %% [markdown]
# #### Basic Info

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cement            824 non-null    float64
#  1   slag              824 non-null    float64
#  2   flyash            824 non-null    float64
#  3   water             824 non-null    float64
#  4   superplasticizer  824 non-null    float64
#  5   coarseaggregate   824 non-null    float64
#  6   fineaggregate     824 non-null    float64
#  7   age               824 non-null    int64
#  8   csMPa             824 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 58.1 KB

# %%
train_df.describe()
# Out:
#            cement        slag      flyash       water  superplasticizer  \
# count  824.000000  824.000000  824.000000  824.000000        824.000000
# mean   279.330340   77.743325   54.551942  181.396602          6.322330
# std    104.650827   88.291707   64.507395   21.416425          5.969006
# min    102.000000    0.000000    0.000000  121.800000          0.000000
# 25%    190.700000    0.000000    0.000000  164.900000          0.000000
# 50%    265.500000   25.000000    0.000000  185.000000          6.550000
# 75%    355.000000  148.925000  118.300000  192.000000         10.300000
# max    540.000000  359.400000  200.100000  247.000000         32.200000
#
#        coarseaggregate  fineaggregate         age       csMPa
# count       824.000000     824.000000  824.000000  824.000000
# mean        971.769660     773.175607   45.793689   36.100874
# std          77.777084      81.127383   61.817539   16.811051
# min         801.000000     594.000000    1.000000    2.330000
# 25%         932.000000     730.300000   14.000000   23.777500
# 50%         967.050000     778.500000   28.000000   34.755000
# 75%        1029.400000     824.000000   56.000000   46.232500
# max        1145.000000     992.600000  365.000000   82.600000

# %% [markdown]
# ### Data Preprocessing pipeline

# %% [markdown]
# Create a data preprocessing pipeline such that it can work on even a single sample.

# %% [markdown]
# Since the data was very clean we didn't require to write complex data preprocessing pipeline.

# %%
def data_preprocessing(df, label=None):
    return((df.drop([label], axis=1), df[label]) if label else df.drop([label], axis=1))

# %% [markdown]
# ### Scoring

# %%
def get_rmse(scores):
    return np.sqrt(-scores)

# %% [markdown]
# ### Rough Model (Linear Regression)

# %%
x_train, y_train = data_preprocessing(train_df, 'csMPa')
lr = LinearRegression(n_jobs=-1)
rmse = get_rmse(cross_val_score(lr, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(lr, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
# Out:
# 10.645783368942636 0.5955563635723153

# %% [markdown]
# ### Rough Model (Decision Tree)

# %%
x_train, y_train = data_preprocessing(train_df, 'csMPa')
dt = DecisionTreeRegressor(random_state=0)
rmse = get_rmse(cross_val_score(dt, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(dt, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
# Out:
# 6.814112986605326 0.8324433124682271

# %% [markdown]
# ### Rough Model (Random Forest)

# %%
x_train, y_train = data_preprocessing(train_df, 'csMPa')
rf = RandomForestRegressor(random_state=0)
rmse = get_rmse(cross_val_score(rf, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(rf, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
rf.fit(x_train, y_train);
# Out:
# 5.4354727452536 0.8931122093632577

# %% [markdown]
# Since RandomForestRegressor is giving good accuracy, let's hyper tune this.

# %% [markdown]
# #### Grid Search for Random Forest

# %%
grid_values = [{'n_estimators': [5, 10, 30, 50, 100, 150, 200, 300, 400, 500], 
               'max_features': ['sqrt', 'auto', 2, 3, 5, 8],
              'bootstrap': [False, True]}
              ]
gs = GridSearchCV(rf, param_grid = grid_values, cv = 5, n_jobs=-1, scoring='neg_mean_squared_error')
gs.fit(x_train, y_train)
print(gs.best_params_)
# Out:
# {'bootstrap': False, 'max_features': 3, 'n_estimators': 200}

# %% [markdown]
# ### Model v1.0

# %%
x_train, y_train = data_preprocessing(train_df, 'csMPa')
rfv1 = RandomForestRegressor(bootstrap=False, n_estimators=200, max_features=3, random_state=0)
rmse = get_rmse(cross_val_score(rfv1, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(rfv1, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
rfv1.fit(x_train, y_train);
# Out:
# 5.079153818364835 0.9071234336039558

# %% [markdown]
# ### Evaluation on Test data

# %%
test_df = pd.read_csv('data/test.csv')
test_df.head(2)
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   500.0    0.0     0.0  200.0               0.0           1125.0
# 1   122.6  183.9     0.0  203.5               0.0            958.2
#
#    fineaggregate  age  csMPa
# 0          613.0    3  26.06
# 1          800.1    7  10.35

# %%
x_test, y_test = data_preprocessing(test_df, 'csMPa')

# %% [markdown]
# #### Using Rough model (Random Forest)

# %%
y_pred = rf.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(rmse, r2)
# Out:
# 4.454678785212585 0.9246556686157521

# %% [markdown]
# #### Using Model v1.0 (Random Forest)

# %%
y_pred = rfv1.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(rmse, r2)
# Out:
# 4.386871585729222 0.926931929467197

# %% [markdown]
# ### Model on full data

# %%
whole_df = pd.read_csv('data/Concrete_Data_Yeh.csv')

# %% [markdown]
# #### Without shuffling the whole data (Model Full)

# %%
x_train, y_train = data_preprocessing(whole_df, 'csMPa')
rf_full = RandomForestRegressor(bootstrap=False, n_estimators=200, max_features=3, random_state=0)
rmse = get_rmse(cross_val_score(rf_full, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(rf_full, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
# Out:
# 9.610758310522233 0.4129638454613276

# %% [markdown]
# #### With shuffling the whole data (Model Shuffle Full)

# %%
shuffled_whole_df = whole_df.sample(frac=1)
x_train, y_train = data_preprocessing(shuffled_whole_df, 'csMPa')
shuffle_rf_full = RandomForestRegressor(bootstrap=False, n_estimators=200, max_features=3, random_state=0)
rmse = get_rmse(cross_val_score(shuffle_rf_full, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(shuffle_rf_full, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
shuffle_rf_full.fit(x_train, y_train);
# Out:
# 4.636863443976058 0.9215055667072363

# %% [markdown]
# There is some weird scenario while training model on full data, but shuffling the data gives us better accuracy.

# %% [markdown]
# ### Plotting RMSE and R2 for Train, Test and Whole data

# %%
x_train, y_train = data_preprocessing(train_df, 'csMPa')
x_test, y_test = data_preprocessing(test_df, 'csMPa')
whole_x_train, whole_y_train = data_preprocessing(shuffled_whole_df, 'csMPa')
plot_dict ={'Epoch': [], 'RMSE': [], 'R2': [], 'Data': []}
for i in [150, 200, 250, 300, 400, 500, 800, 1000]:
    
    plot_dict['Epoch'].append(i)
    
    rfv1 = RandomForestRegressor(bootstrap=False, n_estimators=i, max_features=3, random_state=0)
    rmse = get_rmse(cross_val_score(rfv1, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
    r2 = cross_val_score(rfv1, x_train, y_train, cv=5, scoring='r2')
    
    plot_dict['Data'].append('Train');plot_dict['RMSE'].append(rmse.mean());plot_dict['R2'].append(r2.mean())
    
    rfv1.fit(x_train, y_train);
    y_pred = rfv1.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    plot_dict['Epoch'].append(i)
    plot_dict['Data'].append('Test');plot_dict['RMSE'].append(rmse.mean());plot_dict['R2'].append(r2.mean())
    
    rmse = get_rmse(cross_val_score(rfv1,  whole_x_train, whole_y_train, cv=5, scoring='neg_mean_squared_error'))
    
    r2 = cross_val_score(rfv1,  whole_x_train, whole_y_train, cv=5, scoring='r2')
    
    plot_dict['Epoch'].append(i)
    plot_dict['Data'].append('Whole');plot_dict['RMSE'].append(rmse.mean());plot_dict['R2'].append(r2.mean())

plot_df = pd.DataFrame.from_dict(plot_dict)
plot_df.head(2)
# Out:
#    Epoch      RMSE        R2   Data
# 0    150  5.107263  0.906108  Train
# 1    150  4.399735  0.926503   Test

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
sns.lineplot(x='Epoch',y='RMSE', hue='Data', data=plot_df,ax=ax[0])
sns.lineplot(x='Epoch',y='R2', hue='Data', data=plot_df,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Epoch', ylabel='R2'>

# %% [markdown]
# Epoch 200 looks reasonable choice.

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# #### Using Model v1.0 (Random Forest)

# %%
perm = PermutationImportance(rfv1, random_state=0).fit(x_test, y_test)
eli5.show_weights(perm, feature_names = x_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.7569
#
#                     &plusmn; 0.1287
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3848
#
#                     &plusmn; 0.1245
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cement
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1731
#
#                     &plusmn; 0.0313
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 water
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0908
#
#                     &plusmn; 0.0123
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 superplasticizer
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0593
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 slag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0375
#
#                     &plusmn; 0.0085
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 fineaggregate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0186
#
#                     &plusmn; 0.0074
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 flyash
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0129
#
#                     &plusmn; 0.0038
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 coarseaggregate
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# #### Using Model Shuffle_Full (Random Forest)

# %%
perm = PermutationImportance(shuffle_rf_full, random_state=0).fit(x_test, y_test)
eli5.show_weights(perm, feature_names = x_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.8080
#
#                     &plusmn; 0.1524
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4290
#
#                     &plusmn; 0.1132
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cement
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1963
#
#                     &plusmn; 0.0355
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 water
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1054
#
#                     &plusmn; 0.0100
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 superplasticizer
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0677
#
#                     &plusmn; 0.0117
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 slag
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0537
#
#                     &plusmn; 0.0065
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 fineaggregate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0274
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 coarseaggregate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0261
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 flyash
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ### Training model with only few important features

# %% [markdown]
# #### With top 4 features (on whole data)

# %%
x_train, y_train = data_preprocessing(shuffled_whole_df[['age', 'cement', 'water', 'superplasticizer', 'csMPa']], 
                                      'csMPa')
feat4_rf_full = RandomForestRegressor(bootstrap=False, n_estimators=200, max_features=3, random_state=0)
rmse = get_rmse(cross_val_score(feat4_rf_full, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(feat4_rf_full, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
# Out:
# 6.579965894415889 0.8427828611505654

# %% [markdown]
# #### With top 5 features(on whole data)

# %%
x_train, y_train = data_preprocessing(shuffled_whole_df[['age', 'cement', 'water', 'superplasticizer', 
                                                         'slag', 'csMPa']], 'csMPa')
feat5_rf_full = RandomForestRegressor(bootstrap=False, n_estimators=200, max_features=3, random_state=0)
rmse = get_rmse(cross_val_score(feat5_rf_full, x_train, y_train, cv=5, scoring='neg_mean_squared_error'))
r2 = cross_val_score(feat5_rf_full, x_train, y_train, cv=5, scoring='r2')
print(rmse.mean(), r2.mean())
# Out:
# 4.954479955796784 0.9104419133921997

# %% [markdown]
# ### Finalize the model

# %% [markdown]
#  **feat5_rf_full** is a good model if we want to reduce the cost of collecting the data (i.e with less features) and if we are ready to compromise our accuracy by little.
#
# Otherwise **shuffle_rf_full** is better model.
